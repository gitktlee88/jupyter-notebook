# %%
Long story short, when i joined with Amadeus in 2001 a big project was progressing . 
They had a plan to decommission monolithic mainframe TPF...
which  is IBM mainframe for airlines. 
And also, they were begining to develope New Generation system. 

It's kind of Microservices ( we say, OBE consists of hundreds of APIs), but i reckon
the coloud computing was not seriously considered at the moment.
So they designed with individual Linux boxes for applications.

All the traffic to the new gen system should go through the SI(service integrator) which is
the Frontend Processor/Load Balancer. ( it's like a Gateway Interface )

And OBE take the requests and return the responses to the caller.
That's brief of Amadeus New Gen System   ...  
                                       
In there, our team was mainly in charge of decommissioning communication S/W,
especially, Appl to Appl communication protocols like HTH and Message switching system.                                       
Most of those works has been continued until 2015.
                                       
Later on, our team was working with MQ hub team to migrate legacy Message switching 
system. 
       I've been developing a REST API with Python/Django there.
              it  was just part of the New Gen Project. 

###                                       
MSXViewer project was a standalone API service which is sitting on Linux Apache server.
That means we didn't deploy it on the cloud environment.
Our team didn't use CI/CD at the moment.

Sometimes, 
we used Jira/Confluence for a project management and Bitbucket for resource control.
                                       
Atom and VS CODE is my preferred IDE mostly on windows for developing environment. 

So i would like say my experience is good and  i'm sure that i understand 
    the cloud environment as well.

# %%
Why do you want to work here?
# - xxx is one of the companies which has good business model.
#   Many of high street shops are replaced by online shops, last few years.
    
#   Think of basic requirements for human survival, 
#   xxx has most of items in thousands of offline superstore.
#   Many people still want to buy their food at offline shops rather than online.
- My previous job was in the airline's IT area so i had to study and learn new thechnology
  all the time until today.
  So if i work in your company as a IT developer i believe my long time experience
  will add a lot more power to enhance or develope for the various area.
    like data analyze, warehousing, etc

Why should i hire you?
- My previous job was in the airline's IT area so i had to study and learn new thechnology
  all the time until today.

  I'm sure that i can assure you my passion to adopt new skills like AI and Machine Learning
  which will be future of IT skills.
    
Why do you leave your last job?
-

# %%
            Dec 2019 Circuit Mind, Vascillie

Q1. Can Dictionary take a list as a key?

Q2. Context manager?

Q3. Mixins?

            27 Jan 2020, Genomics England, Michael

Q1. Python 2 vs 3 differences?
       print, string to store as default unicode, range(xrange), __next__(next)
    
Q2. Generator?
       Python generators are a simple way of creating iterators.
        by using yield instead of return

            28 Jan 2020, Sainsbury, Mathew Chubb


Q1. deep copy vs shallow copy 
        deep copy creates a different object  and populates it with the child object
        so changes in the original object is not reflected in the copy.
        
        shalow copy creates a different object  and populates it with the reference of 
        the child object so changes in the original object is reflected in the copy.
        
Q2. Multithreading in python?
        Python Global Interpreter Lock doesn't allow more than one thread to hold 
        the python interpreter at a particular point.
        So, multithreading in python is achieved through context switching.
        
        IO-bound programs spend most of their time waiting for input/output 
        This may be I/O from a network, a database, a file, or even a user.
        
Q3.  Multiprocessing?
        With modern CPU’s generally having more than a single core, 
        we can speed up CPU bound tasks by using the multiprocessing module. 

Q4. Django architecture?        
                                                                                                     / Model
        User <---> Django(wsgi) <---> URL  <---> View - 
                                                                                                    \ Template
            
Q5.  Advantages to use Numpy array over nested List?     
        Numpy is written in C that are packed into simple-to-use module allows same data type array.
        On the other hand,
        Lists are dynamically typed. Therefore, Python must check the data type of each element
        everytime it uses it.

Q6.  5/2 returns quotient in float,  5//2 returns the quotient in integer

Q7. "is"    operator compares the id of the two objects
        "==" operator compares the value of ... 

Q8

# %%
# A dictionary for available coins and bank notes
# coins_notes = {
#     '0.20': 0,   # 0.20
#     '0.50': 0,   # 0.50
#     '1': 0,    # 1
#     '2': 0,    # 2
#     '5': 0,    # 5
#     '10': 0,   # 10
#     '20': 0,   # 20
# }

# class MyFormatter(string.Formatter):
#     def get_value(self, key, args, kwargs):
#         try:
#             return kwargs[str(key)]
#         except KeyError:
#             return super(MyFormatter, self).get_value(key, args, kwargs)
#
# s = 'hello there {5} - you are number {0}'
# d = {'5': 'you'}
# print( MyFormatter().format(s, 1, 2, 3, **d))
# hello there you - you are number 1



# A list for coins and notes
# coins_notes = [[0.20, 0.50, 1, 2, 5, 10, 20], [0, 0, 0, 0, 0, 0, 0]]
# Out:
# [[ 0.12075358]
#  [-0.19219815]
#  [ 0.94553734]
#  [-0.68119223]
#  [ 0.76837869]
#  [ 0.03311223]
#  [-0.38126224]]
