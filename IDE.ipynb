# %%
# jupyter notebook

# %%
#ATOM
install atom
install python 
pip install --upgrade autopep8
pip install --upgrade pycodestyle

Font family & size:     # Atom > Preferences. 

Split screen:    #  Just right-click and choose “Split left” or “Split right”.
    
Duplicate a line:  #  On Windows: Ctrl + Shift + D

Highlight all matching characters:   # On Windows: Alt + F3
        
Easy commenting:  #  On Windows: Ctrl + /
        
BASH terminal:  #  On Windows: Alt + Shift + T
        
Command Palette:  #  On Windows: Ctrl + Shift + P
 
Debugger:
      #  alt-r/option-r: hide/show the debugger view
      #  alt-shift-r/option-shift-r: toggle breakpoint at the current line

      # python -m pdb ./tests/test_main.py  
        
Setting breakpoints:        
    
    - l(ist): displays the source code of the currently running program, with line numbers, 
        for the 10 lines around the current statement.        
    - l 1,999: displays the source code of lines 1-999. I regularly use this to see the source 
        for the entire program. If your program only has 20 lines, it'll just show all 20 lines.
        
    - b(reakpoint): displays a list of current breakpoints.
    - b 10: set a breakpoint at line 10. Breakpoints are referred to by a numeric ID, starting at 1.
    - b main: set a breakpoint at the function named main. The function name must be in the 
        current scope. You can also set breakpoints on functions in other modules in the current scope,
        e.g. b random.randint.
    - b script.py:10: sets a breakpoint at line 10 in script.py. This gives you another way to set 
        breakpoints in another module.
        
    - clear: clears all breakpoints.
    - clear 1: clear breakpoint 1.
    
Stepping through execution:

    - c(ontinue): execute until the program finishes, an exception is thrown, or a breakpoint is hit.
        
    - s(tep): execute the next line, whatever it is (your code, stdlib, third party code, etc.). 
                    Use this when you want to step down into function calls you're interested in.
            
    - n(ext): execute the next line in the current function (will not step into downstream function 
                    calls). Use this when you're only interested in the current function.
        
    - r(eturn): execute the remaining lines in the current function until it returns. 
                    Use this to skip over the rest of the function and go up a level. 
                    For example, if you've stepped down into a function by mistake.
                
    - unt(il) [lineno]: execute until the current line exceeds the current line number. 
                    This is useful when you've stepped into a loop but want to let the loop continue 
                    executing without having to manually step through every iteration. 
                    Without any argument, this command behaves like next 
                    (with the loop skipping behavior, once you've stepped through the loop body once).
                     
Moving up and down the stack:

    - w(here): shows an annotated view of the stack trace, with your current frame marked by >.
                     
    - u(p): move up one frame in the current stack trace. For example, when post-mortem debugging,
                you'll start off on the lowest level of the stack and typically want to move up a few times 
                to help figure out what went wrong.
                     
    - d(own): move down one frame in the current stack trace.
                     
Additional commands and tips:

    - pp <expression>: This will "pretty print" the result of the given expression using the pprint. 
                     
                     
                     
---
10 essential Atom Editor Packages & Setup

PACKAGE LIST:
    
# -Emmet
# -File Icons
# -Atom Live Server
# -Todo
# -Mini-Map
# -Pigments
# -Linter
# -Atom Beautify
# -Ask Stack
# -Highlight Selected

# %%
#VSCODE

Extensions
# - Atom Keymap
# - Live Server
# - Python
# - pylint

- Material Theme, Material Icon Theme
- Prettier
- Bracket Pair Colorizer 2
- indent-rainbow
- Auto Rename Tag
- REST Client
- CSS Peek
- HTML CSS Support
- Live Sass Compiler
- Live Server
- Emmet (I know this is not an extension but it's very useful!)

# %%
#MOGODB atlas

MongoDB / gmail / @Am....88    ,   mongodb.atlas( mongo88 / kc...88 )

# %%
#AWS


// Creating an Archive of an Entire Directory:

(venv3e) D:\vscode employee> tar -cvzf employee.tar.gz d:/vscode employee/*
Extracting an Archive using the Linux tar command
(venv3e) D:\vscode employee> tar -xvzf employee.tar.gz


// OpenSSH using private key on Windows (“Unprotected private key file” error)
// to fix the errors..

cd to the directory where 'test-keypair.pem' is.
    Then, do execute next two commands. 
 {
    icacls .\test-keypair.pem /inheritance:r
    icacls .\test-keypair.pem /grant:r "%username%":"(R)"
 }




D:\data\aws demo> 
ssh -i "test-keypair.pem" ubuntu@ec2-18-223-121-251.us-east-2.compute.amazonaws.com

// To list all the installed packages.
ubuntu@ip-172-31-44-122:~$ dpkg --list

// To completely remove the package you want, type:
ubuntu@ip-172-31-44-122:~$ sudo apt-get purge <package_name>

ubuntu@ip-172-31-44-122:~$ sudo apt-get update
ubuntu@ip-172-31-44-122:~$ sudo apt-get upgrade

ubuntu@ip-172-31-44-122:~$ sudo apt-get install python3-venv
ubuntu@ip-172-31-44-122:~$ python3 -m venv env

ubuntu@ip-172-31-44-122:~$ source env/bin/activate
(env)ubuntu@ip-172-31-44-122:~$ pip install django

(env)ubuntu@ip-172-31-44-122:~$ git clone https://github.com/gitktlee88/vscode-employee.git

(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ sudo apt-get install -y nginx
(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ pip install gunicorn
(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ sudo apt-get install supervisor

(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ cd /etc/supervisor/conf.d/
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ ls
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo touch gunicorn.conf
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo nano gunicorn.conf
    here, change directory=/home/ubuntu/'deploy-django-to-ec2' with your project name

(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo mkdir /var/log/gunicorn
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo supervisorctl reread

(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo supervisorctl update
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo supervisorctl status

(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ cd /etc/nginx/s
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ cd /etc/nginx/sites-available/

(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo touch django.conf
(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo nano django.conf
         change the name with your project instance

(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo sudo nginx -t
           if the test sucess, then move the configuration to the site-enable
(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo ln django.conf /etc/nginx/sites-enabled
(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo service nginx restart
