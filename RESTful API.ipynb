# %%
- Serialization?

is the process of converting an object into a stream of bytes to store the object 
or transmit it to memory, a database, or a file.

It's main purpose is to save the state of an object in order to be able to recreate it
when needed.  (the reverse process is called deserialization)


- Best Practices to Secure REST APIs

Keep it Simple. Secure an API/System – just how secure it needs to be. ...
Always Use HTTPS. ...
Use Password Hash. ...
Never expose information on URLs. ...
Consider OAuth. ...
Consider Adding Timestamp in Request. ...
Input Parameter Validation.

# %%
What is Microservice?

- An architectural aproach to develope applications, where
  application consists of multiple independent components.
- These components are basically, services, communicating through lightweight mechanism.

Difference between Monolithic and Microservice?

- Monolithic:
    1. Centralized Architecture
    2. Easier to test Application and debugging
    3. Cross-cutting concerns such as monitoring, logging is at one application only.
    4. Scaling is issue.
    
- Microservices:
    1. Distributed Architecture (each services are independent and standalone functionality)
    2. Independent Services
    3. Cross-cutting concerns are implemented at each service.
    4. Scaling and deployment is so easy
    5. No technology barrier. for example, each service can use different language

    
How have you created microservice in your project?
...

Microservices provide benefits…
- Strong Module Boundaries: 
    Microservices reinforce modular structure, which is particularly important for larger teams.
- Independent Deployment: 
    Simple services are easier to deploy, and since they are autonomous, are less likely to 
    cause system failures when they go wrong.
- Technology Diversity: 
    With microservices you can mix multiple languages, development frameworks 
    and data-storage technologies.
    
…but come with costs
- Distribution: 
    Distributed systems are harder to program, since remote calls are slow and are always 
    at risk of failure.
- Eventual Consistency: 
    Maintaining strong consistency is extremely difficult for a distributed system, which means 
    everyone has to manage eventual consistency.
- Operational Complexity: 
    You need a mature operations team to manage lots of services, which are being redeployed 
    regularly.

# %%
A RESTful API is an API that uses HTTP requests to GET, PUT, POST and DELETE data.

A RESTful API  is based on representational state transfer (REST) technology.



How RESTful APIs work?

A RESTful API breaks down a transaction to create a series of small modules. 
    Each module addresses a particular underlying part of the transaction. 
    This modularity provides developers with a lot of flexibility, but it can be challenging 
    for developers to design from scratch. 

A RESTful API explicitly takes advantage of HTTP methodologies. 
          They use CRUD,
POST to create that resource; 
GET to read; 
PUT to update a resource, which can be an object, file or block; 
POST to create that resource; 
DELETE to remove it.

With REST, networked components are a resource you request access to -- a black box whose 
implementation details are unclear. 
The presumption is that all calls are stateless; 
    nothing can be retained by the RESTful service between executions.

# %%
https://medium.com/hashmapinc/rest-good-practices-for-api-design-881439796dc9
    
Poorly Designed REST APIs = FRUSTRATION,

 Sometimes I find it difficult and time consuming to integrate/consume APIs 
 due to poor design with little to no documentation. 
This leads to developers (and me) abandoning existing services, and possibly duplicating 
functionality. 

Why Is API Design So Important?

REST APIs are the face of any service, and therefore they should:    
1. Be easy to understand so that integration is straightforward
2. Be well documented, so that semantic behaviors are understood (not just syntactic)
3. Follow accepted standards such as HTTP

Designing and Developing Highly Useful REST APIs:
1. Use Nouns in URI
2. Plurals or Singulars
3. nouns for resources and Let the HTTP Verb Define Action

    Resource      GET(read)         POST(create)        PUT(update)       DELETE(delete)     
    
    /users           returns               creates                     bulk update         delete
                           a list of users    a new user               of user                  all users
        
    /users          returns                not allowed           updates                 delete
                          specipic user                                        specipic user       specipic user
        
4. Don’t Misuse Safe Methods (Idempotency)
5. Depict Resource Hierarchy Through URI
    for example, if a user has posts and we want to retrieve a specific post by user, 
    API can be defined as GET /users/123/posts/1 which will retrieve Post with id 1 
    by user with id 123
    
6. Version Your APIs    
7. Return Representation


10. Stateless Authentication & Authorization


Wrapping Up

Developers need to spend some time while designing REST APIs, as the API can 
make a service very easy to use or extremely complex. 
Additionally, the maturity of the APIs can be easily documented by using 
the Richardson Maturity Model.

# %%
AWS-BASIC
AWS: yahoo / AWSkclkt88
https://signin.aws.amazon.com/signin?redirect_uri=https%3A%2F%2Fconsole.aws.amazon.com%2Fconsole%2Fhome%3Fstate%3DhashArgs%2523%26isauthcode%3Dtrue&client_id=arn%3Aaws%3Aiam%3A%3A015428540659%3Auser%2Fhomepage&forceMobileApp=0
    
// Creating an Archive of an Entire Directory:

(venv3e) D:\vscode employee> tar -cvzf employee.tar.gz d:/vscode employee/*
Extracting an Archive using the Linux tar command
(venv3e) D:\vscode employee> tar -xvzf employee.tar.gz




// OpenSSH using private key on Windows (“Unprotected private key file” error)
// to fix the errors..

cd to the directory where 'test-keypair.pem' is.
    Then, do execute next two commands. 
 {
    icacls .\test-keypair.pem /inheritance:r
    icacls .\test-keypair.pem /grant:r "%username%":"(R)"
 }




D:\data\aws demo> 
ssh -i "test-keypair.pem" ubuntu@ec2-18-223-121-251.us-east-2.compute.amazonaws.com

	// to list all the installed packages.
	ubuntu@ip-172-31-44-122:~$ dpkg --list

	// To completely remove the package you want, type:
	ubuntu@ip-172-31-44-122:~$ sudo apt-get purge <package_name>

ubuntu@ip-172-31-44-122:~$ sudo apt-get update
ubuntu@ip-172-31-44-122:~$ sudo apt-get upgrade

ubuntu@ip-172-31-44-122:~$ sudo apt-get install python3-venv
ubuntu@ip-172-31-44-122:~$ python3 -m venv env

ubuntu@ip-172-31-44-122:~$ source env/bin/activate
(env)ubuntu@ip-172-31-44-122:~$ pip install django

(env)ubuntu@ip-172-31-44-122:~$ git clone https://github.com/gitktlee88/vscode-employee.git

(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ sudo apt-get install -y nginx
(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ pip install gunicorn
(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ sudo apt-get install supervisor

(env)ubuntu@ip-172-31-44-122:~/vscode-employee$ cd /etc/supervisor/conf.d/
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ ls
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo touch gunicorn.conf
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo nano gunicorn.conf
    here, change directory=/home/ubuntu/'deploy-django-to-ec2' with your project name

(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo mkdir /var/log/gunicorn
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo supervisorctl reread

(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo supervisorctl update
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ sudo supervisorctl status

(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ cd /etc/nginx/s
(env)ubuntu@ip-172-31-44-122:/etc/supervisor/conf.d$ cd /etc/nginx/sites-available/

(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo touch django.conf
(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo nano django.conf
         change the name with your project instance

(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo sudo nginx -t
           if the test sucess, then move the configuration to the site-enable
(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo ln django.conf /etc/nginx/sites-enabled
(env)ubuntu@ip-172-31-44-122:/etc/nginx/sites-available$ sudo service nginx restart
